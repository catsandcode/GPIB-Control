# %%
#Import libraries
import numpy as np
from matplotlib import pyplot as plt

#Load array
ar0 = np.load('data/no_virginia_diode.npz')

data = ar0['data']

plt.figure(0)
plt.hist(data[:,1], 50)
plt.figure(1)
plt.hist(data[:,2], 50)
plt.show()
